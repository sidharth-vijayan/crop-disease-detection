# %%
# ── Cell 1: Imports & environment check ───────────────────────────────────────
import os, json, random, time, shutil, warnings
from pathlib import Path
from collections import defaultdict, Counter
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
from tqdm import tqdm
from PIL import Image
 
import cv2
import torch
 
warnings.filterwarnings('ignore')
 
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
 
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device  : {DEVICE}')
if DEVICE.type == 'cuda':
    print(f'GPU     : {torch.cuda.get_device_name(0)}')
 
print(f'OpenCV  : {cv2.__version__}')
print(f'PyTorch : {torch.__version__}')
# Out:
# Device  : cuda
# GPU     : NVIDIA GeForce RTX 4050 Laptop GPU
# OpenCV  : 4.10.0
# PyTorch : 2.7.1+cu118

# %%
# ── Cell 2: Install Ultralytics & verify ──────────────────────────────────────
# Run once — comment out after first successful install
# !pip install ultralytics --quiet
 
from ultralytics import YOLO
import ultralytics
print(f'Ultralytics : {ultralytics.__version__}')
 
# Directory layout this notebook expects
BASE_DIR   = Path('.')          # project root — same as all other increments
YOLO_DIR   = BASE_DIR / 'yolo_data'
LEAF_DIR   = YOLO_DIR / 'leaf_detection'
SPOT_DIR   = YOLO_DIR / 'spot_detection'
 
for d in [YOLO_DIR, LEAF_DIR, SPOT_DIR,
          LEAF_DIR/'images'/'train', LEAF_DIR/'images'/'val',
          LEAF_DIR/'labels'/'train', LEAF_DIR/'labels'/'val',
          SPOT_DIR/'images'/'train', SPOT_DIR/'images'/'val',
          SPOT_DIR/'labels'/'train', SPOT_DIR/'labels'/'val']:
    d.mkdir(parents=True, exist_ok=True)
 
print('Directory structure ready:')
print(f'  {LEAF_DIR}/')
print(f'    images/train|val')
print(f'    labels/train|val')
print(f'  {SPOT_DIR}/')
print(f'    images/train|val')
print(f'    labels/train|val')
